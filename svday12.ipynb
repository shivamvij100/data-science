# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamvij100/data-science/blob/main/svday12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("patrickb1912/ipl-complete-dataset-20082020")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/ipl-complete-dataset-20082020

# %%
import os
file_one,file_two = os.listdir(path)
print('Done')
# Out:
# Done

# %%
file_one_path = path + '/' + file_one
file_two_path = path + '/' + file_two

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
print('Done')
# Out:
# Done

# %%
df_matches = pd.read_csv(file_one_path)
df_deliveries = pd.read_csv(file_two_path)

print('Done')
# Out:
# Done

# %%
df_matches.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %%
df_matches.head(4)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper

# %%
df_deliveries.head(4)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN

# %%
df_deliveries.shape
# Out:
# (260920, 17)

# %%
df_matches.shape
# Out:
# (1095, 20)

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           21 non-null     object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 171.2+ KB

# %%
df_matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df_matches.isna().sum().sort_values(ascending=False)
# Out:
# method             1074
# city                 51
# result_margin        19
# player_of_match       5
# winner                5
# target_runs           3
# target_overs          3
# id                    0
# date                  0
# season                0
# venue                 0
# match_type            0
# toss_decision         0
# toss_winner           0
# team2                 0
# team1                 0
# result                0
# super_over            0
# umpire1               0
# umpire2               0
# dtype: int64

# %%
sns.heatmap(df_matches.isna())
plt.show()

# %%
df_matches.isna().mean().sort_values(ascending=False)*100
# Out:
# method             98.082192
# city                4.657534
# result_margin       1.735160
# player_of_match     0.456621
# winner              0.456621
# target_runs         0.273973
# target_overs        0.273973
# id                  0.000000
# date                0.000000
# season              0.000000
# venue               0.000000
# match_type          0.000000
# toss_decision       0.000000
# toss_winner         0.000000
# team2               0.000000
# team1               0.000000
# result              0.000000
# super_over          0.000000
# umpire1             0.000000
# umpire2             0.000000
# dtype: float64

# %%
df_matches['method'].value_counts()
# Out:
# method
# D/L    21
# Name: count, dtype: int64

# %%
df_matches['method'].fillna('normal method',inplace=True)
print('done')
# Out:
# done
# /tmp/ipython-input-241-4057897002.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_matches['method'].fillna('normal method',inplace=True)

# %%
df_matches['city'].value_counts()
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Visakhapatnam      15
# Durban             15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Navi Mumbai         9
# Indore              9
# Johannesburg        8
# Ranchi              7
# Cuttack             7
# Cape Town           7
# Port Elizabeth      7
# Raipur              6
# Kochi               5
# Mohali              5
# Kanpur              4
# East London         3
# Kimberley           3
# Nagpur              3
# Guwahati            3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
 df_matches[df_matches['city'].isna()]
# Out:
#           id   season city        date   match_type player_of_match  \
# 399   729281     2014  NaN  2014-04-17       League       YS Chahal
# 402   729287     2014  NaN  2014-04-19       League        PA Patel
# 403   729289     2014  NaN  2014-04-19       League       JP Duminy
# 404   729291     2014  NaN  2014-04-20       League      GJ Maxwell
# 406   729295     2014  NaN  2014-04-22       League      GJ Maxwell
# 407   729297     2014  NaN  2014-04-23       League       RA Jadeja
# 408   729299     2014  NaN  2014-04-24       League         CA Lynn
# 409   729301     2014  NaN  2014-04-25       League        AJ Finch
# 410   729303     2014  NaN  2014-04-25       League       MM Sharma
# 413   729309     2014  NaN  2014-04-27       League         M Vijay
# 414   729311     2014  NaN  2014-04-27       League        DR Smith
# 415   729313     2014  NaN  2014-04-28       League  Sandeep Sharma
# 417   729317     2014  NaN  2014-04-30       League         B Kumar
# 757  1216493  2020/21  NaN  2020-09-20       League      MP Stoinis
# 758  1216534  2020/21  NaN  2020-09-21       League       YS Chahal
# 759  1216496  2020/21  NaN  2020-09-22       League       SV Samson
# 761  1216510  2020/21  NaN  2020-09-24       League        KL Rahul
# 762  1216539  2020/21  NaN  2020-09-25       League         PP Shaw
# 809        Kolkata Knight Riders     runs           60.0        192.0
# 811          Sunrisers Hyderabad  wickets           10.0        150.0
# 812               Mumbai Indians     runs           57.0        201.0
# 815               Mumbai Indians  wickets            5.0        157.0
#
#      target_overs super_over         method                umpire1  \
# 399          20.0          N  normal method              Aleem Dar
# 402          20.0          N  normal method              Aleem Dar
# 403          20.0          N  normal method              Aleem Dar
# 404          20.0          N  normal method              BF Bowden
# 406          20.0          N  normal method              M Erasmus
# 407          20.0          N  normal method        HDPK Dharmasena
# 408          20.0          N  normal method              Aleem Dar
# 409          20.0          N  normal method              M Erasmus
# 410          20.0          N  normal method              BF Bowden
# 413          20.0          N  normal method              Aleem Dar
# 414          20.0          N  normal method           AK Chaudhary
# 415          20.0          N  normal method              BF Bowden
# 417          20.0          N  normal method        HDPK Dharmasena
# 757          20.0          Y  normal method           AK Chaudhary
# 758          20.0          N  normal method            AY Dandekar
# 759          20.0          N  normal method          C Shamshuddin
# 761          20.0          N  normal method           AK Chaudhary
# 762          20.0          N  normal method  KN Ananthapadmanabhan
# 764          20.0          N  normal method         RK Illingworth
# 765          20.0          Y  normal method            Nitin Menon
# 767          20.0          N  normal method  KN Ananthapadmanabhan
# 769          20.0          N  normal method           AK Chaudhary
# 771          20.0          N  normal method            VA Kulkarni
# 772          20.0          N  normal method            AY Dandekar
# 773          20.0          N  normal method  KN Ananthapadmanabhan
# 774          20.0          N  normal method            Nitin Menon
# 777          20.0          N  normal method           AK Chaudhary
# 778          20.0          N  normal method  KN Ananthapadmanabhan
# 780          20.0          N  normal method           AK Chaudhary
# 781          20.0          N  normal method               YC Barde
# 783          20.0          N  normal method         RK Illingworth
# 784          20.0          N  normal method           AK Chaudhary
# 785          20.0          N  normal method           AK Chaudhary
# 786          20.0          N  normal method  KN Ananthapadmanabhan
# 788          20.0          N  normal method  KN Ananthapadmanabhan
# 789          20.0          N  normal method           AK Chaudhary
# 791          20.0          Y  normal method            Nitin Menon
# 793          20.0          N  normal method          C Shamshuddin
# 795          20.0          N  normal method            Nitin Menon
# 796          20.0          N  normal method          C Shamshuddin
# 798          20.0          N  normal method            AY Dandekar
# 800          20.0          N  normal method          C Shamshuddin
# 801          20.0          N  normal method  KN Ananthapadmanabhan
# 802          20.0          N  normal method           AK Chaudhary
# 804          20.0          N  normal method          C Shamshuddin
# 806          20.0          N  normal method  KN Ananthapadmanabhan
# 807          20.0          N  normal method               YC Barde
# 809          20.0          N  normal method            Nitin Menon
# 811          20.0          N  normal method          C Shamshuddin
# 812          20.0          N  normal method            CB Gaffaney
# 815          20.0          N  normal method            CB Gaffaney
#
#             umpire2
# 399          S Ravi
# 402    AK Chaudhary
# 403     VA Kulkarni
# 404       M Erasmus
# 406          S Ravi
# 407  RK Illingworth
# 408     VA Kulkarni
# 409          S Ravi
# 410       M Erasmus
# 413     VA Kulkarni
# 414     VA Kulkarni
# 415          S Ravi
# 417       M Erasmus
# 757     Nitin Menon
# 758     Nitin Menon
# 759     VA Kulkarni
# 761      PR Reiffel
# 762  RK Illingworth
# 764    K Srinivasan
# 765      PR Reiffel
# 767   C Shamshuddin
# 769      PR Reiffel
# 771  RK Illingworth
# 772     Nitin Menon
# 773  RK Illingworth
# 774        YC Barde
# 777     Nitin Menon
# 778   C Shamshuddin
# 780      PR Reiffel
# 781      PR Reiffel
# 783    K Srinivasan
# 784      PR Reiffel
# 785     Nitin Menon
# 786   C Shamshuddin
# 788  RK Illingworth
# 789     Nitin Menon
# 791      PR Reiffel
# 793  RK Illingworth
# 795      PR Reiffel
# 796     VA Kulkarni
# 798      PR Reiffel
# 800  RK Illingworth
# 801  RK Illingworth
# 802     Nitin Menon
# 804  RK Illingworth
# 806    K Srinivasan
# 807      PR Reiffel
# 809      PR Reiffel
# 811  RK Illingworth
# 812     Nitin Menon
# 815     Nitin Menon

# %%
df_matches['city'].fillna('UAE',inplace = True)
print('Done')
# Out:
# Done
# /tmp/ipython-input-244-1568223534.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_matches['city'].fillna('UAE',inplace = True)

# %%
df_matches.isna().mean().sort_values(ascending=False)*100
# Out:
# result_margin      1.735160
# player_of_match    0.456621
# winner             0.456621
# target_runs        0.273973
# target_overs       0.273973
# city               0.000000
# season             0.000000
# id                 0.000000
# date               0.000000
# team1              0.000000
# venue              0.000000
# match_type         0.000000
# toss_decision      0.000000
# toss_winner        0.000000
# team2              0.000000
# result             0.000000
# super_over         0.000000
# method             0.000000
# umpire1            0.000000
# umpire2            0.000000
# dtype: float64

# %%
df_matches[df_matches['result_margin'].isna()]
# Out:
#           id   season       city        date match_type player_of_match  \
# 66    392190     2009  Cape Town  2009-04-23     League       YK Pathan
# 130   419121  2009/10    Chennai  2010-03-21     League        J Theron
# 241   501265     2011      Delhi  2011-05-21     League             NaN
# 328   598004     2013  Hyderabad  2013-04-07     League       GH Vihari
# 342   598017     2013  Bangalore  2013-04-16     League         V Kohli
# 416   729315     2014  Abu Dhabi  2014-04-29     League     JP Faulkner
# 475   829741     2015  Ahmedabad  2015-04-21     League        SE Marsh
# 485   829763     2015  Bangalore  2015-04-29     League             NaN
# 511   829813     2015  Bangalore  2015-05-17     League             NaN
# 610  1082625     2017     Rajkot  2017-04-29     League       KH Pandya
# 705  1175365     2019      Delhi  2019-03-30     League         PP Shaw
# 744  1178424     2019  Bengaluru  2019-04-30     League             NaN
# 746  1178426     2019     Mumbai  2019-05-02     League       JJ Bumrah
# 757  1216493  2020/21        UAE  2020-09-20     League      MP Stoinis
# 765  1216547  2020/21        UAE  2020-09-28     League  AB de Villiers
# 790  1216512  2020/21  Abu Dhabi  2020-10-18     League     LH Ferguson
# 791  1216517  2020/21        UAE  2020-10-18     League        KL Rahul
# 835  1254077     2021    Chennai  2021-04-25     League         PP Shaw
# 994  1359519     2023    Lucknow  2023-05-03     League             NaN
#
#                                                  venue  \
# 66                                            Newlands
# 130                    MA Chidambaram Stadium, Chepauk
# 241                                   Feroz Shah Kotla
# 328          Rajiv Gandhi International Stadium, Uppal
# 342                              M Chinnaswamy Stadium
# 416                               Sheikh Zayed Stadium
# 475                       Sardar Patel Stadium, Motera
# 485                              M Chinnaswamy Stadium
# 511                              M Chinnaswamy Stadium
# 610             Saurashtra Cricket Association Stadium
# 705                               Arun Jaitley Stadium
# 744                              M.Chinnaswamy Stadium
# 746                                   Wankhede Stadium
# 757                Dubai International Cricket Stadium
# 765                Dubai International Cricket Stadium
# 790                               Sheikh Zayed Stadium
# 791                Dubai International Cricket Stadium
# 835           MA Chidambaram Stadium, Chepauk, Chennai
# 994  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
#
#                            team1                        team2  \
# 66         Kolkata Knight Riders             Rajasthan Royals
# 130          Chennai Super Kings              Kings XI Punjab
# 241             Delhi Daredevils                Pune Warriors
# 328          Sunrisers Hyderabad  Royal Challengers Bangalore
# 342  Royal Challengers Bangalore             Delhi Daredevils
# 416        Kolkata Knight Riders             Rajasthan Royals
# 475             Rajasthan Royals              Kings XI Punjab
# 485  Royal Challengers Bangalore             Rajasthan Royals
# 511  Royal Challengers Bangalore             Delhi Daredevils
# 610                Gujarat Lions               Mumbai Indians
# 705        Kolkata Knight Riders               Delhi Capitals
# 744  Royal Challengers Bangalore             Rajasthan Royals
# 746               Mumbai Indians          Sunrisers Hyderabad
# 757               Delhi Capitals              Kings XI Punjab
# 765  Royal Challengers Bangalore               Mumbai Indians
# 790        Kolkata Knight Riders          Sunrisers Hyderabad
# 791               Mumbai Indians              Kings XI Punjab
# 835               Delhi Capitals          Sunrisers Hyderabad
# 994         Lucknow Super Giants          Chennai Super Kings
#
#                      toss_winner toss_decision                       winner  \
# 66         Kolkata Knight Riders         field             Rajasthan Royals
# 130          Chennai Super Kings         field              Kings XI Punjab
# 241             Delhi Daredevils           bat                          NaN
# 328  Royal Challengers Bangalore           bat          Sunrisers Hyderabad
# 342  Royal Challengers Bangalore         field  Royal Challengers Bangalore
# 416             Rajasthan Royals           bat             Rajasthan Royals
# 475              Kings XI Punjab         field              Kings XI Punjab
# 485             Rajasthan Royals         field                          NaN
# 511  Royal Challengers Bangalore         field                          NaN
# 610                Gujarat Lions           bat               Mumbai Indians
# 705               Delhi Capitals         field               Delhi Capitals
# 744             Rajasthan Royals         field                          NaN
# 746               Mumbai Indians           bat               Mumbai Indians
# 757              Kings XI Punjab         field               Delhi Capitals
# 765               Mumbai Indians         field  Royal Challengers Bangalore
# 790          Sunrisers Hyderabad         field        Kolkata Knight Riders
# 791               Mumbai Indians           bat              Kings XI Punjab
# 835               Delhi Capitals           bat               Delhi Capitals
# 994          Chennai Super Kings         field                          NaN
#
#         result  result_margin  target_runs  target_overs super_over  \
# 66         tie            NaN        151.0          20.0          Y
# 130        tie            NaN        137.0          20.0          Y
# 241  no result            NaN          NaN           NaN          N
# 328        tie            NaN        131.0          20.0          Y
# 342        tie            NaN        153.0          20.0          Y
# 416        tie            NaN        153.0          20.0          Y
# 475        tie            NaN        192.0          20.0          Y
# 485  no result            NaN          NaN           NaN          N
# 511  no result            NaN        188.0          20.0          N
# 610        tie            NaN        154.0          20.0          Y
# 705        tie            NaN        186.0          20.0          Y
# 744  no result            NaN         63.0           5.0          N
# 746        tie            NaN        163.0          20.0          Y
# 757        tie            NaN        158.0          20.0          Y
# 765        tie            NaN        202.0          20.0          Y
# 790        tie            NaN        164.0          20.0          Y
# 791        tie            NaN        177.0          20.0          Y
# 835        tie            NaN        160.0          20.0          Y
# 994  no result            NaN          NaN           NaN          N
#
#             method          umpire1                umpire2
# 66   normal method        MR Benson              M Erasmus
# 130  normal method      K Hariharan              DJ Harper
# 241  normal method        SS Hazare              RJ Tucker
# 328  normal method     AK Chaudhary                 S Ravi
# 342  normal method        M Erasmus            VA Kulkarni
# 416  normal method        Aleem Dar           AK Chaudhary
# 475  normal method        M Erasmus                 S Ravi
# 485  normal method        JD Cloete              PG Pathak
# 511  normal method  HDPK Dharmasena           K Srinivasan
# 610  normal method     AK Chaudhary            CB Gaffaney
# 705  normal method      AY Dandekar            Nitin Menon
# 744  normal method         NJ Llong              UV Gandhe
# 746  normal method        CK Nandan                 S Ravi
# 757  normal method     AK Chaudhary            Nitin Menon
# 765  normal method      Nitin Menon             PR Reiffel
# 790  normal method        PG Pathak                 S Ravi
# 791  normal method      Nitin Menon             PR Reiffel
# 835  normal method      CB Gaffaney  KN Ananthapadmanabhan
# 994  normal method     AK Chaudhary          NA Patwardhan

# %%
df_matches['result_margin'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1095 entries, 0 to 1094
# Series name: result_margin
# Non-Null Count  Dtype
# --------------  -----
# 1076 non-null   float64
# dtypes: float64(1)
# memory usage: 8.7 KB

# %%
df_matches['result_margin'].fillna(0,inplace=True)
# Out:
# /tmp/ipython-input-248-4158405259.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_matches['result_margin'].fillna(0,inplace=True)

# %%
df_matches[df_matches['winner'].isna()]
# Out:
#           id season       city        date match_type player_of_match  \
# 241   501265   2011      Delhi  2011-05-21     League             NaN
# 485   829763   2015  Bangalore  2015-04-29     League             NaN
# 511   829813   2015  Bangalore  2015-05-17     League             NaN
# 744  1178424   2019  Bengaluru  2019-04-30     League             NaN
# 994  1359519   2023    Lucknow  2023-05-03     League             NaN
#
#                                                  venue  \
# 241                                   Feroz Shah Kotla
# 485                              M Chinnaswamy Stadium
# 511                              M Chinnaswamy Stadium
# 744                              M.Chinnaswamy Stadium
# 994  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
#
#                            team1                team2  \
# 241             Delhi Daredevils        Pune Warriors
# 485  Royal Challengers Bangalore     Rajasthan Royals
# 511  Royal Challengers Bangalore     Delhi Daredevils
# 744  Royal Challengers Bangalore     Rajasthan Royals
# 994         Lucknow Super Giants  Chennai Super Kings
#
#                      toss_winner toss_decision winner     result  \
# 241             Delhi Daredevils           bat    NaN  no result
# 485             Rajasthan Royals         field    NaN  no result
# 511  Royal Challengers Bangalore         field    NaN  no result
# 744             Rajasthan Royals         field    NaN  no result
# 994          Chennai Super Kings         field    NaN  no result
#
#      result_margin  target_runs  target_overs super_over         method  \
# 241            0.0          NaN           NaN          N  normal method
# 485            0.0          NaN           NaN          N  normal method
# 511            0.0        188.0          20.0          N  normal method
# 744            0.0         63.0           5.0          N  normal method
# 994            0.0          NaN           NaN          N  normal method
#
#              umpire1        umpire2
# 241        SS Hazare      RJ Tucker
# 485        JD Cloete      PG Pathak
# 511  HDPK Dharmasena   K Srinivasan
# 744         NJ Llong      UV Gandhe
# 994     AK Chaudhary  NA Patwardhan

# %%
df_matches.fillna({'player_of_match':'No Player of the match',
                   'winner':'No winner'}, inplace= True)
print('Done')
# Out:
# Done

# %%
df_matches.fillna(0,inplace=True)
print('done')
# Out:
# done

# %%
sns.heatmap(df_matches.isna())
# Out:
# <Axes: >

# %%
df_matches['city'].value_counts()
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# UAE                51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Durban             15
# Visakhapatnam      15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Indore              9
# Navi Mumbai         9
# Johannesburg        8
# Ranchi              7
# Port Elizabeth      7
# Cuttack             7
# Cape Town           7
# Raipur              6
# Kochi               5
# Mohali              5
# Kanpur              4
# East London         3
# Kimberley           3
# Nagpur              3
# Guwahati            3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
data_rp = {'Navi Mumbai':'Mumbai',
           'Bengaluru':'Bangalore',
           'Sharjah':'UAE',
           'Abu Dhabi':'UAE','Kimberley':'Cape Town','Dubai':'UAE'}


df_matches.replace(data_rp,inplace = True)
print('Done')
# Out:
# Done

# %%
df_matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df_matches.duplicated('id').value_counts()
# Out:
# False    1095
# Name: count, dtype: int64

# %%
df_matches.drop_duplicates('id',inplace = True)
print('Done')
# Out:
# Done

# %%
#df_datesheet must be in data type

# %%
df_matches['date'] = pd.to_datetime(df_matches['date'])
print('done')
# Out:
# done

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1095 non-null   object
#  3   date             1095 non-null   datetime64[ns]
#  4   match_type       1095 non-null   object
#  5   player_of_match  1095 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1095 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1095 non-null   float64
#  14  target_runs      1095 non-null   float64
#  15  target_overs     1095 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           1095 non-null   object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(15)
# memory usage: 171.2+ KB

# %%
df_matches['venue']
# Out:
# 0                                   M Chinnaswamy Stadium
# 1              Punjab Cricket Association Stadium, Mohali
# 2                                        Feroz Shah Kotla
# 3                                        Wankhede Stadium
# 4                                            Eden Gardens
#                               ...
# 1090    Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                     Narendra Modi Stadium, Ahmedabad
# 1092                     Narendra Modi Stadium, Ahmedabad
# 1093             MA Chidambaram Stadium, Chepauk, Chennai
# 1094             MA Chidambaram Stadium, Chepauk, Chennai
# Name: venue, Length: 1095, dtype: object

# %%
df_matches['venue'].value_counts() .head(16)
# Out:
# venue
# Eden Gardens                                  77
# Wankhede Stadium                              73
# M Chinnaswamy Stadium                         65
# Feroz Shah Kotla                              60
# Rajiv Gandhi International Stadium, Uppal     49
# MA Chidambaram Stadium, Chepauk               48
# Sawai Mansingh Stadium                        47
# Dubai International Cricket Stadium           46
# Wankhede Stadium, Mumbai                      45
# Punjab Cricket Association Stadium, Mohali    35
# Sheikh Zayed Stadium                          29
# Sharjah Cricket Stadium                       28
# MA Chidambaram Stadium, Chepauk, Chennai      28
# Narendra Modi Stadium, Ahmedabad              24
# Maharashtra Cricket Association Stadium       22
# Dr DY Patil Sports Academy, Mumbai            20
# Name: count, dtype: int64

# %%
x = df_matches['venue'].value_counts().head(10).index
y = df_matches['venue'].value_counts().head(10).values


plt.figure(figsize = (7,5))
ax = plt.barh(x,y,color = sns.color_palette('rainbow',10))
plt.bar_label(ax)
plt.title('Top 10 venue by Matches Played')
plt.xticks(rotation = 90)
plt.show()

# %%
df_matches['venue'] = df_matches['venue'].apply(lambda row: row.title().split(',')[0])
print('Done')
# Out:
# Done

# %%
df_matches['venue'].value_counts().reset_index()
# Out:
#                                                 venue  count
# 0                                    Wankhede Stadium    118
# 1                                        Eden Gardens     93
# 2                              Ma Chidambaram Stadium     85
# 3                               M Chinnaswamy Stadium     79
# 4                  Rajiv Gandhi International Stadium     77
# 5                                    Feroz Shah Kotla     60
# 6                              Sawai Mansingh Stadium     57
# 7                 Dubai International Cricket Stadium     46
# 8                          Dr Dy Patil Sports Academy     37
# 9                  Punjab Cricket Association Stadium     35
# 10            Maharashtra Cricket Association Stadium     35
# 11                               Arun Jaitley Stadium     30
# 12                               Sheikh Zayed Stadium     29
# 13                            Sharjah Cricket Stadium     28
# 14                                  Brabourne Stadium     27
# 15       Punjab Cricket Association Is Bindra Stadium     26
# 16                              Narendra Modi Stadium     24
# 17                         Subrata Roy Sahara Stadium     16
# 18  Dr. Y.S. Rajasekhara Reddy Aca-Vdca Cricket St...     15
# 19                              M.Chinnaswamy Stadium     15
# 20                                          Kingsmead     15
# 21  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...     14
# 22       Himachal Pradesh Cricket Association Stadium     13
# 23                                    Supersport Park     12
# 24                               Sardar Patel Stadium     12
# 25             Saurashtra Cricket Association Stadium     10
# 26                             Holkar Cricket Stadium      9
# 27                              Zayed Cricket Stadium      8
# 28                              New Wanderers Stadium      8
# 29                                           Newlands      7
# 30                                   Barabati Stadium      7
# 31                                   St George'S Park      7
# 32                 Jsca International Stadium Complex      7
# 33   Shaheed Veer Narayan Singh International Stadium      6
# 34                                      Nehru Stadium      5
# 35  Maharaja Yadavindra Singh International Cricke...      5
# 36                                         Green Park      4
# 37                                       Buffalo Park      3
# 38                              De Beers Diamond Oval      3
# 39               Vidarbha Cricket Association Stadium      3
# 40                          Barsapara Cricket Stadium      3
# 41                                    Outsurance Oval      2

# %%
df_matches['venue'] = df_matches['venue'].apply(lambda row: row.title().split(',')[0])
print('Done')
# Out:
# Done

# %%
df_matches['venue'].value_counts().head(10)
# Out:
# venue
# Wankhede Stadium                       118
# Eden Gardens                            93
# Ma Chidambaram Stadium                  85
# M Chinnaswamy Stadium                   79
# Rajiv Gandhi International Stadium      77
# Feroz Shah Kotla                        60
# Sawai Mansingh Stadium                  57
# Dubai International Cricket Stadium     46
# Dr Dy Patil Sports Academy              37
# Punjab Cricket Association Stadium      35
# Name: count, dtype: int64

# %%
x = df_matches['venue'].value_counts().head(10).index
y = df_matches['venue'].value_counts().head(10).values


plt.figure(figsize = (7,5))
ax = plt.barh(x,y,color = sns.color_palette('rainbow',10))
plt.bar_label(ax)
plt.title('Top 10 venue by Matches Played')
plt.xticks(rotation = 90)
plt.show()

# %%
df_matches['team1'].value_counts().reset_index()
# Out:
#                           team1  count
# 0   Royal Challengers Bangalore    135
# 1           Chennai Super Kings    128
# 2                Mumbai Indians    123
# 3         Kolkata Knight Riders    121
# 4              Rajasthan Royals    101
# 5               Kings XI Punjab     92
# 6           Sunrisers Hyderabad     86
# 7              Delhi Daredevils     85
# 8                Delhi Capitals     41
# 9               Deccan Chargers     39
# 10                 Punjab Kings     31
# 11         Lucknow Super Giants     23
# 12                Pune Warriors     23
# 13               Gujarat Titans     21
# 14                Gujarat Lions     16
# 15  Royal Challengers Bengaluru      9
# 16         Kochi Tuskers Kerala      7
# 17       Rising Pune Supergiant      7
# 18      Rising Pune Supergiants      7

# %%
team_name_rp = {'Delhi Daredevils':'Delhi Capitals',
                'Royal Challengers Bangalore':'Royal Challengers Bengaluru',
                'Kings XI Punjab':'Punjab Kings',
                'Rising Pune Supergiant':'Rising Pune Supergiants',
                'Pune Warriors':'Rising Pune Supergiants'}
df_matches[['team1','team2']]=df_matches[['team1','team2']].replace(team_name_rp)
print('Done')
# Out:
# Done

# %%
df_matches
# Out:
#            id   season        city       date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore 2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh 2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi 2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai 2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata 2008-04-20       League        DJ Hussey
# ...       ...      ...         ...        ...          ...              ...
# 1090  1426307     2024   Hyderabad 2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad 2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad 2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai 2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai 2024-05-26        Final         MA Starc
#
#                                    venue                        team1  \
# 0                  M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 1     Punjab Cricket Association Stadium                 Punjab Kings
# 2                       Feroz Shah Kotla               Delhi Capitals
# 3                       Wankhede Stadium               Mumbai Indians
# 4                           Eden Gardens        Kolkata Knight Riders
# ...                                  ...                          ...
# 1090  Rajiv Gandhi International Stadium                 Punjab Kings
# 1091               Narendra Modi Stadium          Sunrisers Hyderabad
# 1092               Narendra Modi Stadium  Royal Challengers Bengaluru
# 1093              Ma Chidambaram Stadium          Sunrisers Hyderabad
# 1094              Ma Chidambaram Stadium          Sunrisers Hyderabad
#
#                             team2                  toss_winner toss_decision  \
# 0           Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1             Chennai Super Kings          Chennai Super Kings           bat
# 2                Rajasthan Royals             Rajasthan Royals           bat
# 3     Royal Challengers Bengaluru               Mumbai Indians           bat
# 4                 Deccan Chargers              Deccan Chargers           bat
# ...                           ...                          ...           ...
# 1090          Sunrisers Hyderabad                 Punjab Kings           bat
# 1091        Kolkata Knight Riders          Sunrisers Hyderabad           bat
# 1092             Rajasthan Royals             Rajasthan Royals         field
# 1093             Rajasthan Royals             Rajasthan Royals         field
# 1094        Kolkata Knight Riders          Sunrisers Hyderabad           bat
#
#                            winner   result  result_margin  target_runs  \
# 0           Kolkata Knight Riders     runs          140.0        223.0
# 1             Chennai Super Kings     runs           33.0        241.0
# 2                Delhi Daredevils  wickets            9.0        130.0
# 3     Royal Challengers Bangalore  wickets            5.0        166.0
# 4           Kolkata Knight Riders  wickets            5.0        111.0
# ...                           ...      ...            ...          ...
# 1090          Sunrisers Hyderabad  wickets            4.0        215.0
# 1091        Kolkata Knight Riders  wickets            8.0        160.0
# 1092             Rajasthan Royals  wickets            4.0        173.0
# 1093          Sunrisers Hyderabad     runs           36.0        176.0
# 1094        Kolkata Knight Riders  wickets            8.0        114.0
#
#       target_overs super_over         method                umpire1  \
# 0             20.0          N  normal method              Asad Rauf
# 1             20.0          N  normal method              MR Benson
# 2             20.0          N  normal method              Aleem Dar
# 3             20.0          N  normal method               SJ Davis
# 4             20.0          N  normal method              BF Bowden
# ...            ...        ...            ...                    ...
# 1090          20.0          N  normal method            Nitin Menon
# 1091          20.0          N  normal method           AK Chaudhary
# 1092          20.0          N  normal method  KN Ananthapadmanabhan
# 1093          20.0          N  normal method            Nitin Menon
# 1094          20.0          N  normal method          J Madanagopal
#
#                    umpire2
# 0              RE Koertzen
# 1               SL Shastri
# 2           GA Pratapkumar
# 3                DJ Harper
# 4              K Hariharan
# ...                    ...
# 1090             VK Sharma
# 1091              R Pandit
# 1092  MV Saidharshan Kumar
# 1093             VK Sharma
# 1094           Nitin Menon
#
# [1095 rows x 20 columns]

# %%
df_matches['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Punjab Kings                    24
# Lucknow Super Giants            24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# No winner                        5
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
df_matches['match_type'].value_counts()
# Out:
# match_type
# League                1029
# Final                   17
# Qualifier 2             14
# Qualifier 1             14
# Eliminator              11
# Semi Final               6
# Elimination Final        3
# 3rd Place Play-Off       1
# Name: count, dtype: int64

# %%
df_matches[df_matches['match_type']== 'Final']['winner'].value_counts()
# Out:
# winner
# Chennai Super Kings      5
# Mumbai Indians           5
# Kolkata Knight Riders    3
# Deccan Chargers          1
# Rajasthan Royals         1
# Sunrisers Hyderabad      1
# Gujarat Titans           1
# Name: count, dtype: int64

# %%
plt.title('Highest ipl session winning team')
df_matches[df_matches['match_type'] == 'Final']['winner'].value_counts().plot(kind = 'pie',autopct = '%.2f%%')
plt.show()

# %%
final_match = df_matches[df_matches['match_type'] == 'Final']
final_match
# Out:
#            id   season          city       date match_type player_of_match  \
# 57     336040  2007/08        Mumbai 2008-06-01      Final       YK Pathan
# 114    392239     2009  Johannesburg 2009-05-24      Final        A Kumble
# 174    419165  2009/10        Mumbai 2010-04-25      Final        SK Raina
# 247    501271     2011       Chennai 2011-05-28      Final         M Vijay
# 321    548381     2012       Chennai 2012-05-27      Final        MS Bisla
# 397    598073     2013       Kolkata 2013-05-26      Final      KA Pollard
# 457    734049     2014     Bangalore 2014-06-01      Final       MK Pandey
# 516    829823     2015       Kolkata 2015-05-24      Final       RG Sharma
# 576    981019     2016     Bangalore 2016-05-29      Final     BCJ Cutting
# 635   1082650     2017     Hyderabad 2017-05-21      Final       KH Pandya
# 695   1136620     2018        Mumbai 2018-05-27      Final       SR Watson
# 755   1181768     2019     Hyderabad 2019-05-12      Final       JJ Bumrah
# 815   1237181  2020/21           UAE 2020-11-10      Final        TA Boult
# 875   1254117     2021           UAE 2021-10-15      Final    F du Plessis
# 949   1312200     2022     Ahmedabad 2022-05-29      Final       HH Pandya
# 1023  1370353     2023     Ahmedabad 2023-05-29      Final       DP Conway
# 1094  1426312     2024       Chennai 2024-05-26      Final        MA Starc
#
#                                     venue                        team1  \
# 57             Dr Dy Patil Sports Academy          Chennai Super Kings
# 114                 New Wanderers Stadium  Royal Challengers Bengaluru
# 174            Dr Dy Patil Sports Academy          Chennai Super Kings
# 247                Ma Chidambaram Stadium          Chennai Super Kings
# 321                Ma Chidambaram Stadium        Kolkata Knight Riders
# 397                          Eden Gardens          Chennai Super Kings
# 457                 M Chinnaswamy Stadium        Kolkata Knight Riders
# 516                          Eden Gardens               Mumbai Indians
# 576                 M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 635    Rajiv Gandhi International Stadium               Mumbai Indians
# 695                      Wankhede Stadium          Sunrisers Hyderabad
# 755    Rajiv Gandhi International Stadium               Mumbai Indians
# 815   Dubai International Cricket Stadium               Delhi Capitals
# 875   Dubai International Cricket Stadium          Chennai Super Kings
# 949                 Narendra Modi Stadium             Rajasthan Royals
# 1023                Narendra Modi Stadium               Gujarat Titans
# 1094               Ma Chidambaram Stadium          Sunrisers Hyderabad
#
#                             team2                  toss_winner toss_decision  \
# 57               Rajasthan Royals             Rajasthan Royals         field
# 114               Deccan Chargers  Royal Challengers Bangalore         field
# 174                Mumbai Indians          Chennai Super Kings           bat
# 247   Royal Challengers Bengaluru          Chennai Super Kings           bat
# 321           Chennai Super Kings          Chennai Super Kings           bat
# 397                Mumbai Indians               Mumbai Indians           bat
# 457                  Punjab Kings        Kolkata Knight Riders         field
# 516           Chennai Super Kings          Chennai Super Kings         field
# 576           Sunrisers Hyderabad          Sunrisers Hyderabad           bat
# 635       Rising Pune Supergiants               Mumbai Indians           bat
# 695           Chennai Super Kings          Chennai Super Kings         field
# 755           Chennai Super Kings               Mumbai Indians           bat
# 815                Mumbai Indians               Delhi Capitals           bat
# 875         Kolkata Knight Riders        Kolkata Knight Riders         field
# 949                Gujarat Titans             Rajasthan Royals           bat
# 1023          Chennai Super Kings          Chennai Super Kings         field
# 1094        Kolkata Knight Riders          Sunrisers Hyderabad           bat
#
#                      winner   result  result_margin  target_runs  \
# 57         Rajasthan Royals  wickets            3.0        164.0
# 114         Deccan Chargers     runs            6.0        144.0
# 174     Chennai Super Kings     runs           22.0        169.0
# 247     Chennai Super Kings     runs           58.0        206.0
# 321   Kolkata Knight Riders  wickets            5.0        191.0
# 397          Mumbai Indians     runs           23.0        149.0
# 457   Kolkata Knight Riders  wickets            3.0        200.0
# 516          Mumbai Indians     runs           41.0        203.0
# 576     Sunrisers Hyderabad     runs            8.0        209.0
# 635          Mumbai Indians     runs            1.0        130.0
# 695     Chennai Super Kings  wickets            8.0        179.0
# 755          Mumbai Indians     runs            1.0        150.0
# 815          Mumbai Indians  wickets            5.0        157.0
# 875     Chennai Super Kings     runs           27.0        193.0
# 949          Gujarat Titans  wickets            7.0        131.0
# 1023    Chennai Super Kings  wickets            5.0        171.0
# 1094  Kolkata Knight Riders  wickets            8.0        114.0
#
#       target_overs super_over         method          umpire1         umpire2
# 57            20.0          N  normal method        BF Bowden     RE Koertzen
# 114           20.0          N  normal method      RE Koertzen      SJA Taufel
# 174           20.0          N  normal method      RE Koertzen      SJA Taufel
# 247           20.0          N  normal method        Asad Rauf      SJA Taufel
# 321           20.0          N  normal method        BF Bowden      SJA Taufel
# 397           20.0          N  normal method  HDPK Dharmasena      SJA Taufel
# 457           20.0          N  normal method  HDPK Dharmasena    BNJ Oxenford
# 516           20.0          N  normal method  HDPK Dharmasena  RK Illingworth
# 576           20.0          N  normal method  HDPK Dharmasena    BNJ Oxenford
# 635           20.0          N  normal method         NJ Llong          S Ravi
# 695           20.0          N  normal method        M Erasmus          S Ravi
# 755           20.0          N  normal method         IJ Gould     Nitin Menon
# 815           20.0          N  normal method      CB Gaffaney     Nitin Menon
# 875           20.0          N  normal method      Nitin Menon  RK Illingworth
# 949           20.0          N  normal method      CB Gaffaney     Nitin Menon
# 1023          15.0          N            D/L      Nitin Menon       RJ Tucker
# 1094          20.0          N  normal method    J Madanagopal     Nitin Menon

# %%
final_match['Winning year'] = final_match['date'].dt.year
print('Done')
# Out:
# Done
# /tmp/ipython-input-277-2850961424.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final
# 1094        Kolkata Knight Riders          Sunrisers Hyderabad  ...
#
#                      winner   result result_margin  target_runs  target_overs  \
# 57         Rajasthan Royals  wickets           3.0        164.0          20.0
# 114         Deccan Chargers     runs           6.0        144.0          20.0
# 174     Chennai Super Kings     runs          22.0        169.0          20.0
# 247     Chennai Super Kings     runs          58.0        206.0          20.0
# 321   Kolkata Knight Riders  wickets           5.0        191.0          20.0
# 397          Mumbai Indians     runs          23.0        149.0          20.0
# 457   Kolkata Knight Riders  wickets           3.0        200.0          20.0
# 516          Mumbai Indians     runs          41.0        203.0          20.0
# 576     Sunrisers Hyderabad     runs           8.0        209.0          20.0
# 635          Mumbai Indians     runs           1.0        130.0          20.0
# 695     Chennai Super Kings  wickets           8.0        179.0          20.0
# 755          Mumbai Indians     runs           1.0        150.0          20.0
# 815          Mumbai Indians  wickets           5.0        157.0          20.0
# 875     Chennai Super Kings     runs          27.0        193.0          20.0
# 949          Gujarat Titans  wickets           7.0        131.0          20.0
# 1023    Chennai Super Kings  wickets           5.0        171.0          15.0
# 1094  Kolkata Knight Riders  wickets           8.0        114.0          20.0
#
#       super_over         method          umpire1         umpire2 Winning year
# 57             N  normal method        BF Bowden     RE Koertzen         2008
# 114            N  normal method      RE Koertzen      SJA Taufel         2009
# 174            N  normal method      RE Koertzen      SJA Taufel         2010
# 247            N  normal method        Asad Rauf      SJA Taufel         2011
# 321            N  normal method        BF Bowden      SJA Taufel         2012
# 397            N  normal method  HDPK Dharmasena      SJA Taufel         2013
# 457            N  normal method  HDPK Dharmasena    BNJ Oxenford         2014
# 516            N  normal method  HDPK Dharmasena  RK Illingworth         2015
# 576            N  normal method  HDPK Dharmasena    BNJ Oxenford         2016
# 635            N  normal method         NJ Llong          S Ravi         2017
# 695            N  normal method        M Erasmus          S Ravi         2018
# 755            N  normal method         IJ Gould     Nitin Menon         2019
# 815            N  normal method      CB Gaffaney     Nitin Menon         2020
# 875            N  normal method      Nitin Menon  RK Illingworth         2021
# 949            N  normal method      CB Gaffaney     Nitin Menon         2022
# 1023           N            D/L      Nitin Menon       RJ Tucker         2023
# 1094           N  normal method    J Madanagopal     Nitin Menon         2024
#
# [17 rows x 21 columns]

# %%
final_match[['Winning year','winner']].sort_values('winner')
# Out:
#       Winning year                 winner
# 174           2010    Chennai Super Kings
# 247           2011    Chennai Super Kings
# 1023          2023    Chennai Super Kings
# 695           2018    Chennai Super Kings
# 875           2021    Chennai Super Kings
# 114           2009        Deccan Chargers
# 949           2022         Gujarat Titans
# 1094          2024  Kolkata Knight Riders
# 321           2012  Kolkata Knight Riders
# 457           2014  Kolkata Knight Riders
# 397           2013         Mumbai Indians
# 516           2015         Mumbai Indians
# 635           2017         Mumbai Indians
# 755           2019         Mumbai Indians
# 815           2020         Mumbai Indians
# 57            2008       Rajasthan Royals
# 576           2016    Sunrisers Hyderabad

# %%
final_match['result'].value_counts()
# Out:
# result
# runs       9
# wickets    8
# Name: count, dtype: int64

# %%
df_matches.groupby('venue')['result'].value_counts()
# Out:
# venue                  result
# Arun Jaitley Stadium   runs       16
#                        wickets    13
#                        tie         1
# Barabati Stadium       runs        4
#                        wickets     3
#                                   ..
# Wankhede Stadium       wickets    64
#                        runs       53
#                        tie         1
# Zayed Cricket Stadium  wickets     5
#                        runs        3
# Name: count, Length: 97, dtype: int64

# %%
df_matches.groupby('venue')['result'].value_counts().reset_index()
# Out:
#                     venue   result  count
# 0    Arun Jaitley Stadium     runs     16
# 1    Arun Jaitley Stadium  wickets     13
# 2    Arun Jaitley Stadium      tie      1
# 3        Barabati Stadium     runs      4
# 4        Barabati Stadium  wickets      3
# ..                    ...      ...    ...
# 92       Wankhede Stadium  wickets     64
# 93       Wankhede Stadium     runs     53
# 94       Wankhede Stadium      tie      1
# 95  Zayed Cricket Stadium  wickets      5
# 96  Zayed Cricket Stadium     runs      3
#
# [97 rows x 3 columns]

# %%
final_match.groupby('venue')['result'].value_counts().reset_index().sort_values(by='count',ascending=False)
# Out:
#                                   venue   result  count
# 4                          Eden Gardens     runs      2
# 9                 Narendra Modi Stadium  wickets      2
# 11   Rajiv Gandhi International Stadium     runs      2
# 7                Ma Chidambaram Stadium  wickets      2
# 0            Dr Dy Patil Sports Academy     runs      1
# 3   Dubai International Cricket Stadium  wickets      1
# 2   Dubai International Cricket Stadium     runs      1
# 1            Dr Dy Patil Sports Academy  wickets      1
# 5                 M Chinnaswamy Stadium     runs      1
# 8                Ma Chidambaram Stadium     runs      1
# 6                 M Chinnaswamy Stadium  wickets      1
# 10                New Wanderers Stadium     runs      1
# 12                     Wankhede Stadium  wickets      1

# %%
final_match.groupby('venue')['result'].value_counts().reset_index().sort_values(by='venue')
# Out:
#                                   venue   result  count
# 0            Dr Dy Patil Sports Academy     runs      1
# 1            Dr Dy Patil Sports Academy  wickets      1
# 2   Dubai International Cricket Stadium     runs      1
# 3   Dubai International Cricket Stadium  wickets      1
# 4                          Eden Gardens     runs      2
# 5                 M Chinnaswamy Stadium     runs      1
# 6                 M Chinnaswamy Stadium  wickets      1
# 7                Ma Chidambaram Stadium  wickets      2
# 8                Ma Chidambaram Stadium     runs      1
# 9                 Narendra Modi Stadium  wickets      2
# 10                New Wanderers Stadium     runs      1
# 11   Rajiv Gandhi International Stadium     runs      2
# 12                     Wankhede Stadium  wickets      1

# %%
df_matches.groupby('venue')['result'].value_counts().reset_index().sort_values(by='venue')
# Out:
#                     venue   result  count
# 0    Arun Jaitley Stadium     runs     16
# 1    Arun Jaitley Stadium  wickets     13
# 2    Arun Jaitley Stadium      tie      1
# 3        Barabati Stadium     runs      4
# 4        Barabati Stadium  wickets      3
# ..                    ...      ...    ...
# 93       Wankhede Stadium     runs     53
# 92       Wankhede Stadium  wickets     64
# 94       Wankhede Stadium      tie      1
# 95  Zayed Cricket Stadium  wickets      5
# 96  Zayed Cricket Stadium     runs      3
#
# [97 rows x 3 columns]

# %% [markdown]
# day 13

# %%
final_match[['Winning year','winner']].sort_values('Winning year')
# Out:
#       Winning year                 winner
# 57            2008       Rajasthan Royals
# 114           2009        Deccan Chargers
# 174           2010    Chennai Super Kings
# 247           2011    Chennai Super Kings
# 321           2012  Kolkata Knight Riders
# 397           2013         Mumbai Indians
# 457           2014  Kolkata Knight Riders
# 516           2015         Mumbai Indians
# 576           2016    Sunrisers Hyderabad
# 635           2017         Mumbai Indians
# 695           2018    Chennai Super Kings
# 755           2019         Mumbai Indians
# 815           2020         Mumbai Indians
# 875           2021    Chennai Super Kings
# 949           2022         Gujarat Titans
# 1023          2023    Chennai Super Kings
# 1094          2024  Kolkata Knight Riders

# %%
df_matches['winner'].value_counts().head(10)
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Name: count, dtype: int64

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1095 non-null   object
#  3   date             1095 non-null   datetime64[ns]
#  4   match_type       1095 non-null   object
#  5   player_of_match  1095 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1095 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1095 non-null   float64
#  14  target_runs      1095 non-null   float64
#  15  target_overs     1095 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           1095 non-null   object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(15)
# memory usage: 171.2+ KB

# %%
num_cols = df_matches.describe().columns
cat_cols = df_matches.describe(include = 'O').columns

# %%
print(num_cols)
# Out:
# Index(['id', 'date', 'result_margin', 'target_runs', 'target_overs'], dtype='object')

# %%
print(cat_cols)
# Out:
# Index(['season', 'city', 'match_type', 'player_of_match', 'venue', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'super_over', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
for i in cat_cols:
  try:
    temp_df = df_matches[i].value_counts().head(10)
    x = temp_df.index
    y = temp_df.values

    plt.title(f'Top 10 Analysis by {i}')
    plt.bar(x,y,color = sns.color_palette('cool',10))
    plt.xticks(rotation = 90)
    plt.show()
  except:
    pass

# %%
for i in cat_cols:
  try:
    temp_df = df_matches[i].value_counts().head(10).sort_values(10)
    x = temp_df.index
    y = temp_df.values

    plt.title(f'Top 10 Analysis by {i}')
    ax = plt.barh(x,y,color = sns.color_palette('cool',10))
    plt.bar_lable(ax)
    plt.xticks(rotation = 90)
    plt.show()
  except:
    pass

# %%
plt.figure(figsize = (30,45))
for j,i in enumerate(cat_cols):
  temp_df = df_matches[i].value_counts().head(10).sort_values(ascending = True)
  x = temp_df.index
  y = temp_df.values

  plt.subplot(7,2,j+1)
  plt.title(f'Top 10 Analysis by {i}')
  colors = ['cool','mako','rainbow','magma','hot']
  import random
  ax = plt.barh(x,y,color = sns.color_palette(random.choice(colors),10))
  plt.bar_label(ax)
  plt.xticks(rotation = 90)

plt.savefig('All_Categorical_Analysis.jpeg')
plt.show()
print('Done')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-295-2972162214.py in <cell line: 0>()
#       5   y = temp_df.values
#       6
# ----> 7   plt.subplot(7,2,j+1)
#       8   plt.title(f'Top 10 Analysis by {i}')
#       9   colors = ['cool','mako','rainbow','magma','hot']
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1548
#    1549     # First, search for an existing subplot with a matching spec.
# -> 1550     key = SubplotSpec._from_subplot_args(fig, args)
#    1551
#    1552     for ax in fig.axes:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     587         else:
#     588             if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 589                 raise ValueError(
#     590                     f"num must be an integer with 1 <= num <= {rows*cols}, "
#     591                     f"not {num!r}"
#
# ValueError: num must be an integer with 1 <= num <= 14, not 15

# %%
num_cols = df_matches.describe().columns

num_cols = list(num_cols)
num_cols.remove('id')
num_cols.remove('date')
num_cols.remove('target_overs')
num_cols

if 'result_margin' not in num_cols:
  num_cols.append('result_margin')

print(num_cols)
# Out:
# ['result_margin', 'target_runs']

# %%
plt.figure(figsize = (10,4))
for j,i in enumerate(num_cols):
  plt.subplot(1,2,j+1)
  plt.title(f'Distribution Analysis for {i}')
  plt.hist(df_matches[i],color = 'red')
plt.show()

# %%
# Numerical Histogram
plt.figure(figsize = (10,4))
for j,i in enumerate(num_cols):
  plt.subplot(1,2,j+1)
  plt.title(f'Distribution Analysis for {i}')
  plt.hist(df_matches[i],color = 'red')
plt.show()

# %%
# Numerical Histogram
plt.figure(figsize = (10,4))
for j,i in enumerate(num_cols):
  plt.subplot(1,2,j+1)
  plt.title(f'Distribution Analysis for {i}')
  sns.histplot(df_matches[i],color = 'blue',kde = True) #Kernel Density Estimator (KDE)
plt.show()

# %%
df_matches[df_matches['target_runs'] == df_matches['target_overs'].max()]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, match_type, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, target_runs, target_overs, super_over, method, umpire1, umpire2]
# Index: []

# %%
df_matches['result'].value_counts()
# Out:
# result
# wickets      578
# runs         498
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
temp_df = df_matches[df_matches['winner'] != 'No winner']
temp_df['target_runs'] == temp_df['target_runs'].min()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1090    False
# 1091    False
# 1092    False
# 1093    False
# 1094    False
# Name: target_runs, Length: 1090, dtype: bool

# %%
df_matches[df_matches['target_runs'] == df_matches['target_runs'].max()]
# Out:
#            id season       city       date match_type player_of_match  \
# 1053  1426268   2024  Bangalore 2024-04-15     League         TM Head
#
#                       venue                team1                        team2  \
# 1053  M Chinnaswamy Stadium  Sunrisers Hyderabad  Royal Challengers Bengaluru
#
#                       toss_winner toss_decision               winner result  \
# 1053  Royal Challengers Bengaluru         field  Sunrisers Hyderabad   runs
#
#       result_margin  target_runs  target_overs super_over         method  \
# 1053           25.0        288.0          20.0          N  normal method
#
#            umpire1   umpire2
# 1053  AK Chaudhary  R Pandit

# %%
temp_df = df_matches[(df_matches['winner'] != 'No winner') & (df_matches['method'] == 'Normal method')]

temp_df[temp_df['target_runs'] == temp_df['target_runs'].min()]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, match_type, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, target_runs, target_overs, super_over, method, umpire1, umpire2]
# Index: []

# %%
df_matches['target_runs'].value_counts().sort_index().head(20)
# Out:
# target_runs
# 0.0     3
# 43.0    1
# 48.0    1
# 52.0    1
# 53.0    1
# 54.0    1
# 58.0    1
# 61.0    1
# 63.0    1
# 66.0    1
# 68.0    2
# 69.0    2
# 71.0    3
# 74.0    1
# 81.0    2
# 82.0    1
# 83.0    1
# 85.0    1
# 89.0    2
# 90.0    1
# Name: count, dtype: int64

# %%
df_matches[df_matches['date'].dt.year == 2017].sort_values(by = 'target_runs')
# Out:
#           id season        city       date   match_type    player_of_match  \
# 633  1082648   2017   Bangalore 2017-05-17   Eliminator    NM Coulter-Nile
# 611  1082626   2017  Chandigarh 2017-04-30       League     Sandeep Sharma
# 630  1082645   2017        Pune 2017-05-14       League         JD Unadkat
# 634  1082649   2017   Bangalore 2017-05-19  Qualifier 2          KV Sharma
# 619  normal method  KN Ananthapadmanabhan    AK Chaudhary
# 584  normal method           AK Chaudhary   C Shamshuddin
# 610  normal method           AK Chaudhary     CB Gaffaney
# 628  normal method           AK Chaudhary     Nitin Menon
# 616  normal method  KN Ananthapadmanabhan  A Nand Kishore
# 609  normal method  KN Ananthapadmanabhan       M Erasmus
# 581  normal method                 S Ravi       VK Sharma
# 621  normal method            AY Dandekar   C Shamshuddin
# 586  normal method            Nitin Menon       CK Nandan
# 595  normal method            AY Dandekar      A Deshmukh
# 607  normal method               NJ Llong          S Ravi
# 604  normal method         A Nand Kishore          S Ravi
# 614  normal method              M Erasmus   C Shamshuddin
# 631  normal method              CK Nandan   C Shamshuddin
# 593  normal method  KN Ananthapadmanabhan   C Shamshuddin
# 613  normal method           AK Chaudhary     CB Gaffaney
# 632  normal method                 S Ravi   C Shamshuddin
# 580  normal method           AK Chaudhary   C Shamshuddin
# 624  normal method         A Nand Kishore          S Ravi
# 594  normal method            Nitin Menon       CK Nandan
# 627  normal method  KN Ananthapadmanabhan       CK Nandan
# 587  normal method             A Deshmukh        NJ Llong
# 589  normal method         A Nand Kishore          S Ravi
# 590  normal method            AY Dandekar        NJ Llong
# 629  normal method         A Nand Kishore          S Ravi
# 601  normal method            AY Dandekar      A Deshmukh
# 592  normal method         A Nand Kishore          S Ravi
# 583  normal method            Nitin Menon       CK Nandan
# 605  normal method            AY Dandekar        NJ Llong
# 579  normal method            Nitin Menon       CK Nandan
# 578  normal method         A Nand Kishore          S Ravi
# 615  normal method               YC Barde     Nitin Menon
# 599  normal method            CB Gaffaney     Nitin Menon
# 591  normal method               YC Barde     Nitin Menon
# 602  normal method           AK Chaudhary       M Erasmus
# 622  normal method         A Nand Kishore       VK Sharma
# 597  normal method            CB Gaffaney        NJ Llong
# 625  normal method               YC Barde    AK Chaudhary
# 598  normal method              M Erasmus   C Shamshuddin
# 585  normal method            AY Dandekar          S Ravi
# 577  normal method            AY Dandekar        NJ Llong
# 608  normal method            Nitin Menon       CK Nandan
# 617  normal method              M Erasmus     Nitin Menon
# 612  normal method            AY Dandekar          S Ravi
# 620  normal method            Nitin Menon       CK Nandan
# 596  normal method                 S Ravi       VK Sharma
# 626  normal method             A Deshmukh  A Nand Kishore

# %%
# Min Target Runs which team?
temp_df = df_matches[(df_matches['winner'] != 'No winner') & (df_matches['method'] == 'Normal method')]

temp_df[temp_df['target_runs'] == temp_df['target_runs'].min()]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, match_type, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, target_runs, target_overs, super_over, method, umpire1, umpire2]
# Index: []

# %%
df_matches['target_runs'].value_counts().sort_index().head(20)
# Out:
# target_runs
# 0.0     3
# 43.0    1
# 48.0    1
# 52.0    1
# 53.0    1
# 54.0    1
# 58.0    1
# 61.0    1
# 63.0    1
# 66.0    1
# 68.0    2
# 69.0    2
# 71.0    3
# 74.0    1
# 81.0    2
# 82.0    1
# 83.0    1
# 85.0    1
# 89.0    2
# 90.0    1
# Name: count, dtype: int64

# %%
df_matches[df_matches['date'].dt.year == 2017].sort_values(by = 'winner')[['winner','result','result_margin']]
# Out:
#                           winner   result  result_margin
# 591             Delhi Daredevils     runs           51.0
# 615             Delhi Daredevils  wickets            6.0
# 617             Delhi Daredevils  wickets            7.0
# 627             Delhi Daredevils     runs            7.0
# 625             Delhi Daredevils  wickets            2.0
# 585             Delhi Daredevils     runs           97.0
# 599                Gujarat Lions  wickets            4.0
# 622                Gujarat Lions  wickets            6.0
# 589                Gujarat Lions  wickets            7.0
# 606                Gujarat Lions  wickets            7.0
# 618              Kings XI Punjab     runs           19.0
# 624              Kings XI Punjab     runs           14.0
# 626              Kings XI Punjab     runs            7.0
# 602              Kings XI Punjab     runs           26.0
# 611              Kings XI Punjab  wickets           10.0
# 580              Kings XI Punjab  wickets            6.0
# 584              Kings XI Punjab  wickets            8.0
# 603        Kolkata Knight Riders     runs           82.0
# 633        Kolkata Knight Riders  wickets            7.0
# 579        Kolkata Knight Riders  wickets           10.0
# 587        Kolkata Knight Riders  wickets            8.0
# 594        Kolkata Knight Riders  wickets            4.0
# 621        Kolkata Knight Riders  wickets            6.0
# 605        Kolkata Knight Riders  wickets            7.0
# 590        Kolkata Knight Riders     runs           17.0
# 607        Kolkata Knight Riders  wickets            7.0
# 613               Mumbai Indians  wickets            5.0
# 629               Mumbai Indians     runs            9.0
# 610               Mumbai Indians      tie            0.0
# 620               Mumbai Indians     runs          146.0
# 635               Mumbai Indians     runs            1.0
# 586               Mumbai Indians  wickets            4.0
# 588               Mumbai Indians  wickets            4.0
# 592               Mumbai Indians  wickets            6.0
# 600               Mumbai Indians     runs           14.0
# 634               Mumbai Indians  wickets            6.0
# 598               Mumbai Indians  wickets            8.0
# 583               Mumbai Indians  wickets            4.0
# 593       Rising Pune Supergiant     runs           27.0
# 630       Rising Pune Supergiant  wickets            9.0
# 619       Rising Pune Supergiant     runs           12.0
# 632       Rising Pune Supergiant     runs           20.0
# 616       Rising Pune Supergiant  wickets            4.0
# 614       Rising Pune Supergiant  wickets            5.0
# 578       Rising Pune Supergiant  wickets            7.0
# 601       Rising Pune Supergiant  wickets            6.0
# 604       Rising Pune Supergiant     runs            3.0
# 609       Rising Pune Supergiant     runs           61.0
# 631  Royal Challengers Bangalore     runs           10.0
# 596  Royal Challengers Bangalore     runs           21.0
# 581  Royal Challengers Bangalore     runs           15.0
# 608          Sunrisers Hyderabad     runs           26.0
# 582          Sunrisers Hyderabad  wickets            9.0
# 623          Sunrisers Hyderabad  wickets            7.0
# 595          Sunrisers Hyderabad     runs            5.0
# 597          Sunrisers Hyderabad     runs           15.0
# 612          Sunrisers Hyderabad     runs           48.0
# 628          Sunrisers Hyderabad  wickets            8.0
# 577          Sunrisers Hyderabad     runs           35.0

# %%
df_matches.iloc[603,:]
# Out:
# id                                     1082617
# season                                    2017
# city                                   Kolkata
# date                       2017-04-23 00:00:00
# match_type                              League
# player_of_match                NM Coulter-Nile
# venue                             Eden Gardens
# team1                    Kolkata Knight Riders
# team2              Royal Challengers Bengaluru
# toss_winner        Royal Challengers Bangalore
# toss_decision                            field
# winner                   Kolkata Knight Riders
# result                                    runs
# result_margin                             82.0
# target_runs                              132.0
# target_overs                              20.0
# super_over                                   N
# method                           normal method
# umpire1                            CB Gaffaney
# umpire2                              CK Nandan
# Name: 603, dtype: object

# %%
df_matches.groupby(['venue', 'team1'])['target_runs'].agg(['max', 'min', 'mean'])
# Out:
#                                                      max    min        mean
# venue                 team1
# Arun Jaitley Stadium  Chennai Super Kings          224.0  219.0  221.500000
#                       Delhi Capitals               258.0  130.0  186.333333
#                       Kolkata Knight Riders        186.0  128.0  157.000000
#                       Mumbai Indians               169.0  169.0  169.000000
#                       Punjab Kings                 168.0  144.0  158.666667
# ...                                                  ...    ...         ...
# Zayed Cricket Stadium Kolkata Knight Riders        172.0  172.0  172.000000
#                       Mumbai Indians               236.0  156.0  196.000000
#                       Punjab Kings                 136.0  136.0  136.000000
#                       Royal Challengers Bengaluru   93.0   93.0   93.000000
#                       Sunrisers Hyderabad          142.0  142.0  142.000000
#
# [221 rows x 3 columns]

# %%
df_matches.pivot_table(index=' Year ', columns='team1', values='target_runs')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-324-2732030400.py in <cell line: 0>()
# ----> 1 df_matches.pivot_table(index=' Year ', columns='team1', values='target_runs')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9507         from pandas.core.reshape.pivot import pivot_table
#    9508
# -> 9509         return pivot_table(
#    9510             self,
#    9511             values=values,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     100         return table.__finalize__(data, method="pivot_table")
#     101
# --> 102     table = __internal_pivot_table(
#     103         data,
#     104         values,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/pivot.py in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     170
#     171     observed_bool = False if observed is lib.no_default else observed
# --> 172     grouped = data.groupby(keys, observed=observed_bool, sort=sort, dropna=dropna)
#     173     if observed is lib.no_default and any(
#     174         ping._passed_categorical for ping in grouped._grouper.groupings
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: ' Year '

# %%
for i, col in enumerate(df_matches.columns):
    print(f"{i}: '{col}'")
# Out:
# 0: 'id'
# 1: 'season'
# 2: 'city'
# 3: 'date'
# 4: 'match_type'
# 5: 'player_of_match'
# 6: 'venue'
# 7: 'team1'
# 8: 'team2'
# 9: 'toss_winner'
# 10: 'toss_decision'
# 11: 'winner'
# 12: 'result'
# 13: 'result_margin'
# 14: 'target_runs'
# 15: 'target_overs'
# 16: 'super_over'
# 17: 'method'
# 18: 'umpire1'
# 19: 'umpire2'

# %%
df_matches.pivot_table(index='season', columns='team1', values='target_runs')
# Out:
# team1    Chennai Super Kings  Deccan Chargers  Delhi Capitals  Gujarat Lions  \
# season
# 2007/08           163.333333       174.428571      166.285714            NaN
# 2009              164.727273       151.400000      131.777778            NaN
# 2009/10           164.900000       161.285714      173.571429            NaN
# 2011              166.375000       162.285714      135.428571            NaN
# 2012              154.666667       158.250000      171.600000            NaN
# 2013              172.000000              NaN      152.500000            NaN
# 2014              172.222222              NaN      139.000000            NaN
# 2015              164.777778              NaN      146.000000            NaN
# 2016                     NaN              NaN      156.857143     156.222222
# 2017                     NaN              NaN      185.285714     180.571429
# 2018              187.500000              NaN      176.111111            NaN
# 2019              158.833333              NaN      164.000000            NaN
# 2020/21           147.250000              NaN      172.090909            NaN
# 2021              182.200000              NaN      152.142857            NaN
# 2022              168.000000              NaN      178.800000            NaN
# 2023              196.777778              NaN      165.200000            NaN
# 2024              189.000000              NaN      205.000000            NaN
#
# team1    Gujarat Titans  Kochi Tuskers Kerala  Kolkata Knight Riders  \
# season
# 2007/08             NaN                   NaN             127.000000
# 2009                NaN                   NaN             147.500000
# 2009/10             NaN                   NaN             161.857143
# 2011                NaN            145.571429             128.428571
# 2012                NaN                   NaN             155.000000
# 2013                NaN                   NaN             145.000000
# 2014                NaN                   NaN             163.375000
# 2015                NaN                   NaN             172.833333
# 2016                NaN                   NaN             147.571429
# 2017                NaN                   NaN             165.000000
# 2018                NaN                   NaN             180.666667
# 2019                NaN                   NaN             173.111111
# 2020/21             NaN                   NaN             161.600000
# 2021                NaN                   NaN             164.500000
# 2022         163.285714                   NaN             159.200000
# 2023         193.625000                   NaN             174.571429
# 2024         173.333333                   NaN             210.333333
#
# team1    Lucknow Super Giants  Mumbai Indians  Punjab Kings  Rajasthan Royals  \
# season
# 2007/08                   NaN      143.285714    186.285714        159.428571
# 2009                      NaN      146.000000    135.833333               NaN
# 2009/10                   NaN      174.666667    173.714286        156.857143
# 2011                      NaN      153.000000    181.714286        143.571429
# 2012                      NaN      142.875000    150.750000        168.375000
# 2013                      NaN      176.333333    165.875000        152.888889
# 2014                      NaN      173.714286    164.750000        155.857143
# 2015                      NaN      184.000000    149.571429        176.714286
# 2016                      NaN      160.285714    168.857143               NaN
# 2017                      NaN      161.400000    163.714286               NaN
# 2018                      NaN      182.222222    158.571429        149.500000
# 2019                      NaN      166.100000    179.285714        159.800000
# 2020/21                   NaN      186.444444    179.500000        176.250000
# 2021                      NaN      157.000000    153.222222        166.142857
# 2022               179.500000      165.200000    173.777778        176.846154
# 2023               160.285714      177.500000    179.555556        190.000000
# 2024               181.750000      175.800000    170.750000        172.800000
#
# team1    Rising Pune Supergiants  Royal Challengers Bengaluru  \
# season
# 2007/08                      NaN                   157.142857
# 2009                         NaN                   151.187500
# 2009/10                      NaN                   162.111111
# 2011                  144.142857                   156.000000
# 2012                  150.750000                   173.714286
# 2013                  144.750000                   161.375000
# 2014                         NaN                   165.000000
# 2015                         NaN                   158.375000
# 2016                  153.142857                   201.375000
# 2017                  163.571429                   149.333333
# 2018                         NaN                   179.000000
# 2019                         NaN                   155.555556
# 2020/21                      NaN                   162.000000
# 2021                         NaN                   155.875000
# 2022                         NaN                   172.333333
# 2023                         NaN                   181.333333
# 2024                         NaN                   196.333333
#
# team1    Sunrisers Hyderabad
# season
# 2007/08                  NaN
# 2009                     NaN
# 2009/10                  NaN
# 2011                     NaN
# 2012                     NaN
# 2013              135.625000
# 2014              161.857143
# 2015              141.142857
# 2016              140.375000
# 2017              155.250000
# 2018              155.333333
# 2019              181.750000
# 2020/21           175.333333
# 2021              140.000000
# 2022              182.666667
# 2023              179.285714
# 2024              200.500000

# %%
all_team_year_df = df_matches.pivot_table(index = 'season',columns ='team1',values = 'target_runs')

# %%
plt.figure(figsize = (10,10))
# pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.float_format', '{:.2f}'.format)
sns.heatmap(all_team_year_df,annot = True)
plt.show()

# %%
all_team_year_df = df_matches.pivot_table(index = 'season',columns ='team1',values = 'target_runs',aggfunc= 'min')
all_team_year_df = all_team_year_df.round(0)

plt.figure(figsize = (15,7))
# pd.options.display.float_format = '{:.2f}'.format
sns.heatmap(all_team_year_df,fmt="",annot = True,cmap='mako')
plt.title('IPL all Session Team Minimum score')
plt.show()

# %%
all_team_year_df = df_matches.pivot_table(index = 'season',columns ='team1',values = 'target_runs',aggfunc= 'max')
all_team_year_df = all_team_year_df.round(0)

plt.figure(figsize = (15,7))
# pd.options.display.float_format = '{:.2f}'.format
sns.heatmap(all_team_year_df,fmt="",annot = True,cmap='cool')
plt.title('IPL all Session Team Maximum score')
plt.show()

# %%
team 2 year wise target runs

# %%
all_team_year_df = df_matches.pivot_table(index = 'season',columns ='team2',values = 'target_runs',aggfunc= 'min')
all_team_year_df = all_team_year_df.round(0)

plt.figure(figsize = (15,7))
# pd.options.display.float_format = '{:.2f}'.format
sns.heatmap(all_team_year_df,fmt="",annot = True,cmap='mako')
plt.title('IPL all Session Team Minimum score')
plt.show()

# %%
df_matches.loc[50:55,['team1','team2','result']]
# Out:
#                           team1                team2   result
# 50        Kolkata Knight Riders         Punjab Kings  wickets
# 51             Rajasthan Royals       Mumbai Indians  wickets
# 52              Deccan Chargers  Chennai Super Kings  wickets
# 53  Royal Challengers Bengaluru       Mumbai Indians  wickets
# 54                 Punjab Kings     Rajasthan Royals     runs
# 55               Delhi Capitals     Rajasthan Royals     runs

# %%
df_matches.iloc[50:55,[7,8,12]]
# Out:
#                           team1                team2   result
# 50        Kolkata Knight Riders         Punjab Kings  wickets
# 51             Rajasthan Royals       Mumbai Indians  wickets
# 52              Deccan Chargers  Chennai Super Kings  wickets
# 53  Royal Challengers Bengaluru       Mumbai Indians  wickets
# 54                 Punjab Kings     Rajasthan Royals     runs

# %%
df_matches['date'] = pd.to_datetime(df_matches['date'])

# %%
df_matches['year'] = df_matches['date'].dt.year

# %%
rows = df_matches[df_matches['year'] >= 2016].index
df_matches.iloc[rows, -3:]
# Out:
#                     umpire1               umpire2  year
# 517         HDPK Dharmasena             CK Nandan  2016
# 518                  S Ravi         C Shamshuddin  2016
# 519            AK Chaudhary           VA Kulkarni  2016
# 520         HDPK Dharmasena             VK Sharma  2016
# 521             Nitin Menon                S Ravi  2016
# ...                     ...                   ...   ...
# 1090            Nitin Menon             VK Sharma  2024
# 1091           AK Chaudhary              R Pandit  2024
# 1092  KN Ananthapadmanabhan  MV Saidharshan Kumar  2024
# 1093            Nitin Menon             VK Sharma  2024
# 1094          J Madanagopal           Nitin Menon  2024
#
# [578 rows x 3 columns]

# %%
df_deliveries.iloc[129729,:]
# Out:
# match_id                      980961
# inning                             2
# batting_team        Delhi Daredevils
# bowling_team           Gujarat Lions
# over                               1
# ball                               3
# batter                       RR Pant
# bowler                   DS Kulkarni
# non_striker                Q de Kock
# batsman_runs                       4
# extra_runs                         0
# total_runs                         4
# extras_type                      NaN
# is_wicket                          0
# player_dismissed                 NaN
# dismissal_kind                   NaN
# fielder                          NaN
# Name: 129729, dtype: object

# %%
df_deliveries.iloc[119957,:]
# Out:
# match_id                         829799
# inning                                2
# batting_team            Kings XI Punjab
# bowling_team        Sunrisers Hyderabad
# over                                 16
# ball                                  1
# batter                         AR Patel
# bowler                          B Kumar
# non_striker                   DA Miller
# batsman_runs                          1
# extra_runs                            0
# total_runs                            1
# extras_type                         NaN
# is_wicket                             0
# player_dismissed                    NaN
# dismissal_kind                      NaN
# fielder                             NaN
# Name: 119957, dtype: object

# %%
df_deliveries.isna().sum().sort_values(ascending = False)
# Out:
# fielder             251566
# dismissal_kind      247970
# player_dismissed    247970
# extras_type         246795
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# non_striker              0
# bowler                   0
# batter                   0
# ball                     0
# total_runs               0
# extra_runs               0
# batsman_runs             0
# is_wicket                0
# dtype: int64

# %%
df_deliveries.loc[:,['fielder','dismissal_kind','player_dismissed','extras_type']]
# Out:
#        fielder dismissal_kind player_dismissed extras_type
# 0          NaN            NaN              NaN     legbyes
# 1          NaN            NaN              NaN         NaN
# 2          NaN            NaN              NaN       wides
# 3          NaN            NaN              NaN         NaN
# 4          NaN            NaN              NaN         NaN
# ...        ...            ...              ...         ...
# 260915     NaN            NaN              NaN         NaN
# 260916     NaN            NaN              NaN         NaN
# 260917     NaN            NaN              NaN         NaN
# 260918     NaN            NaN              NaN         NaN
# 260919     NaN            NaN              NaN         NaN
#
# [260920 rows x 4 columns]

# %%
normal_cols = ['fielder','dismissal_kind','player_dismissed','extras_type']

# %%
for i in normal_cols:
    print(f"analysis for {i}\n\n")
    display(df_deliveries[i].value_counts().head(10))
# Out:
# analysis for fielder
# fielder
# MS Dhoni          220
# KD Karthik        199
# AB de Villiers    141
# RV Uthappa        133
# V Kohli           131
# WP Saha           131
# SK Raina          119
# RA Jadeja         116
# SV Samson         115
# RG Sharma         111
# Name: count, dtype: int64
# analysis for dismissal_kind
# dismissal_kind
# caught                   8063
# bowled                   2212
# run out                  1114
# lbw                       800
# caught and bowled         367
# stumped                   358
# retired hurt               15
# hit wicket                 15
# obstructing the field       3
# retired out                 3
# Name: count, dtype: int64
# analysis for player_dismissed
# player_dismissed
# RG Sharma     223
# V Kohli       207
# S Dhawan      193
# KD Karthik    184
# RV Uthappa    180
# SK Raina      171
# DA Warner     164
# AT Rayudu     155
# AM Rahane     154
# SV Samson     144
# Name: count, dtype: int64
# analysis for extras_type
# extras_type
# wides      8380
# legbyes    4001
# noballs    1069
# byes        673
# penalty       2
# Name: count, dtype: int64

# %%
plt.title('Checking Null values Distribution!!')
sns.heatmap(df_deliveries.isna())
plt.show()

# %%
df_deliveries.fillna('Unknown', inplace = True)
print('Done')
# Out:
# Done

# %%
plt.title('Checking Null values Distribution!!')
sns.heatmap(df_deliveries.isna())
plt.show()

# %%
df_deliveries.sample()
# Out:
#         match_id  inning    batting_team    bowling_team  over  ball   batter  \
# 253388   1426278       1  Delhi Capitals  Gujarat Titans    11     1  RR Pant
#
#            bowler non_striker  batsman_runs  extra_runs  total_runs  \
# 253388  MM Sharma    AR Patel             4           0           4
#
#        extras_type  is_wicket player_dismissed dismissal_kind  fielder
# 253388     Unknown          0          Unknown        Unknown  Unknown

# %%
player_df = df_deliveries[df_deliveries['batter'] == 'DA Miller']
player_df['batsman_runs'].value_counts().sort_index()
# Out:
# batsman_runs
# 0    726
# 1    918
# 2    184
# 3      2
# 4    207
# 6    134
# Name: count, dtype: int64

# %%
player_df = df_deliveries[df_deliveries['batter'] == 'DA Miller']
x = player_df['batsman_runs'].value_counts().sort_index().plot(kind = 'pie',autopct = '%.2f%%')
y=plt.show()

# %%
batsman = 'DA Miller'

player_df =df_deliveries[df_deliveries['batter'] == batsman]

x = player_df['batsman_runs'].value_counts().sort_index().index
y = player_df['batsman_runs'].value_counts().sort_index().values
plt.figure(figsize = (3,2))
plt.title(f'Analysis for {batsman}')
plt.barh(x,y,color = sns.color_palette('magma',7))
plt.show()

# %%
batsman = 'DA Miller'

player_df =df_deliveries[df_deliveries['batter'] == batsman]

x = player_df['batsman_runs'].value_counts().sort_index().index
y = player_df['batsman_runs'].value_counts().sort_index().values
plt.figure(figsize = (4,2))
plt.title(f'Analysis for {batsman}')
ax = plt.bar(x,y,color = sns.color_palette('magma',7))
plt.bar_label(ax)
plt.show()

total_runs = player_df['batsman_runs'].sum()

print(f'{batsman} Total Runs in IPL History: {total_runs}')
# Out:
# DA Miller Total Runs in IPL History: 2924

# %%
player_df.groupby('bowler')['batsman_runs'].agg(['sum','mean'])
# Out:
#                 sum  mean
# bowler
# A Ashish Reddy   12  2.00
# A Mishra         68  1.31
# A Nehra          19  1.19
# A Nortje         31  2.21
# A Zampa           6  1.20
# ...             ...   ...
# YS Chahal        77  1.71
# Yash Dayal       17  1.21
# Yash Thakur      11  1.83
# Yuvraj Singh     11  2.20
# Z Khan            2  0.33
#
# [178 rows x 2 columns]

# %%
batsman = 'DA Miller'

def get_player_performance(batsman):
    player_df = df_deliveries[df_deliveries['batter'] == batsman]

    x = player_df['batsman_runs'].value_counts().sort_index().index
    y = player_df['batsman_runs'].value_counts().sort_index().values
    plt.figure(figsize=(4, 2))
    plt.title(f'Analysis for {batsman}')
    ax = plt.bar(x, y, color=sns.color_palette('magma', 7))
    plt.bar_label(ax)
    plt.show()

    total_runs = player_df['batsman_runs'].sum()
    print(f'{batsman} Total Runs in IPL History: {total_runs}')

    print(f'Batsman {batsman} Top 10 Performance Against Bowlers')
    performance_df = player_df.groupby('bowler')['batsman_runs'].agg(['sum', 'mean']).reset_index().sort_values(by='sum', ascending=False).head(10)

    display(performance_df)

# Call the function
get_player_performance(batsman)
# Out:
# DA Miller Total Runs in IPL History: 2924
# Batsman DA Miller Top 10 Performance Against Bowlers
#                 bowler  sum  mean
# 129          RA Jadeja  111  1.66
# 122           R Ashwin   82  1.12
# 173          YS Chahal   77  1.71
# 1             A Mishra   68  1.31
# 45            HV Patel   63  1.50
# 14          Avesh Khan   61  1.52
# 118          PP Chawla   60  1.18
# 90   M Prasidh Krishna   59  1.69
# 165           UT Yadav   55  1.34
# 151          SP Narine   51  1.34

# %%
import random

all_batsman = df_deliveries['batter'].unique().tolist()

for i in random.choices(all_batsman, k=5):
    get_player_performance_stats(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-398-2352722887.py in <cell line: 0>()
#       4
#       5 for i in random.choices(all_batsman, k=5):
# ----> 6     get_player_performance_stats(i)
#
# NameError: name 'get_player_performance_stats' is not defined
